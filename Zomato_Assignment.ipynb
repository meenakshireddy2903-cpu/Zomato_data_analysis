# %% [markdown]
# <a href="https://colab.research.google.com/github/meenakshireddy2903-cpu/Zomato_data_analysis/blob/main/Zomato_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ZOMATO BANGLORE DATA ANALYSIS**

# %% [markdown]
# **Objective:**
# To perform Exploratory Data Analysis (EDA) on the Zomato Bangalore dataset and generate
# meaningful business insights using Python.

# %%
#Importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading the dataset
df = pd.read_excel("zomato_rest_data.xlsx")
df
# Out:
#        Unnamed: 0                                                url  \
# 0               0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1               1  https://www.zomato.com/bangalore/spice-elephan...
# 2               2  https://www.zomato.com/SanchurroBangalore?cont...
# 3               3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4               4  https://www.zomato.com/bangalore/grand-village...
# ...           ...                                                ...
# 51712       51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713       51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714       51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715       51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716       51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# ...

# %% [markdown]
# # **Exploratory Data Analysis**

# %% [markdown]
# #Task 1: Data Understanding & Cleaning

# %% [markdown]
# **1: Dataset Exploration**

# %%
#1.Displaying first 5 rows
df.head(5)
# Out:
#    Unnamed: 0                                                url  \
# 0           0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1           1  https://www.zomato.com/bangalore/spice-elephan...
# 2           2  https://www.zomato.com/SanchurroBangalore?cont...
# 3           3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4           4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# ...

# %%
#2.Displaying the shape of dataset
df.shape
# Out:
# (51717, 18)

# %%
#3.List of column names
df.columns
# Out:
# Index(['Unnamed: 0', 'url', 'address', 'name', 'online_order', 'book_table',
#        'rate', 'votes', 'phone', 'location', 'rest_type', 'dish_liked',
#        'cuisines', 'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
#4. Checking data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   51717 non-null  int64
#  1   url                          51717 non-null  object
#  2   address                      51717 non-null  object
#  3   name                         51717 non-null  object
#  4   online_order                 51717 non-null  object
#  5   book_table                   51717 non-null  object
#  6   rate                         43942 non-null  object
#  7   votes                        51717 non-null  int64
#  8   phone                        50509 non-null  object
#  9   location                     51696 non-null  object
#  10  rest_type                    51490 non-null  object
#  11  dish_liked                   23639 non-null  object
#  12  cuisines                     51672 non-null  object
# ...

# %%
#5. Identifying missing values
df.isnull().sum()
# Out:
# Unnamed: 0                         0
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %% [markdown]
# **2. Data Cleaning**

# %% [markdown]
# **Performing necessary cleaning steps:**

# %%
#Removing Unamed : 0 column
df = df.drop("Unnamed: 0",axis = 1)
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
#Drop duplicate rows
df.drop_duplicates(inplace = True)
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
columns_to_drop = ["url","phone","dish_liked","reviews_list","menu_item"]
existing_columns = [col for col in columns_to_drop if col in df.columns]
df = df.drop(existing_columns, axis=1)
df
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   address                      51717 non-null  object
#  1   name                         51717 non-null  object
#  2   online_order                 51717 non-null  object
#  3   book_table                   51717 non-null  object
#  4   rate                         43942 non-null  object
#  5   votes                        51717 non-null  int64
#  6   location                     51696 non-null  object
#  7   rest_type                    51490 non-null  object
#  8   cuisines                     51672 non-null  object
#  9   approx_cost(for two people)  51371 non-null  object
#  10  listed_in(type)              51717 non-null  object
#  11  listed_in(city)              51717 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 4.7+ MB

# %% [markdown]
# **Handling Address column**

# %%
#Handling Address Column
df["address"].unique() #It has 0 null values
# Out:
# array(['942, 21st Main Road, 2nd Stage, Banashankari, Bangalore',
#        '2nd Floor, 80 Feet Road, Near Big Bazaar, 6th Block, Kathriguppe, 3rd Stage, Banashankari, Bangalore',
#        '1112, Next to KIMS Medical College, 17th Cross, 2nd Stage, Banashankari, Bangalore',
#        ...,
#        'Cessna Business Park, Sarjapur Ã\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â\x82Ã\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x82Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â\x96 Marathahalli Outer Ring Road, Kadubeesanahalli, Bellandur Post, Bengaluru, Karnataka',
#        '44, Kodigehalli to Hoodi Main Road, Mahadevapura Post, KR Puram, Bangalore',
#        '139/C1, Next To GR Tech Park, Pattandur Agrahara, ITPL, Main Road, Whitefield, Bangalore'],
#       dtype=object)

# %% [markdown]
# **Handling Name column**

# %%
#Handling Name Column
df["name"].unique() #It has 0 null values
# Out:
# array(['Jalsa', 'Spice Elephant', 'San Churro Cafe', ..., 'Nawabs Empire',
#        'SeeYa Restaurant',
#        'Plunge - Sheraton Grand Bengaluru Whitefield Hotel &...'],
#       dtype=object)

# %% [markdown]
# **Handling Online_order column**

# %%
#Handling Online_order column
df["online_order"].unique() #It has 0 null values
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# **Handling book_table column**

# %%
#Handling Book_table column
df["book_table"].unique() #It has 0 null values
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# **Handling Rate column**

# %%
#Handling Rate column
df["rate"].unique()
# Replacing unwanted values with numpy.nan
df["rate"] = df["rate"].replace("NEW", np.nan)
df["rate"] = df["rate"].replace("-", np.nan)

# Removing '/5' from rating values.,.str.replace()
df["rate"] = df["rate"].astype(str).str.replace("/5", "")

# Converting rating column to float datatype.
df["rate"] = pd.to_numeric(df["rate"], errors='coerce')
# Checking datatype of rate column
df["rate"].dtype
# Checking number of missing values in rate column
df["rate"].isnull().sum()
#Rechecking unique values in rate column
df["rate"].unique()
# Filling missing rating values with average rating (3.7)
df["rate"] = df["rate"].fillna(3.7)
# Checking unique values again after filling null values
df["rate"].unique()
# Out:
# array([4.1, 3.8, 3.7, 3.6, 4.6, 4. , 4.2, 3.9, 3.1, 3. , 3.2, 3.3, 2.8,
#        4.4, 4.3, 2.9, 3.5, 2.6, 3.4, 4.5, 2.5, 2.7, 4.7, 2.4, 2.2, 2.3,
#        4.8, 4.9, 2.1, 2. , 1.8])

# %% [markdown]
# **Handling Votes column**

# %%
#Handling Votes Column
df["votes"].unique() #It has 0 null values
# Out:
# array([ 775,  787,  918, ..., 4957, 2382,  843])

# %% [markdown]
# **Handling Location column**

# %%
#Handling Location column
df["location"].unique()
# Checking missing values in location column
df["location"].isnull().sum()
# Removing rows where location is missing
df.dropna(subset=["location"], inplace=True)
df["location"].isnull().sum() #Removed null values
# Out:
# np.int64(0)

# %% [markdown]
# **Handling rest_type column**

# %%
#Dropping restype column as it is not required for analysis
df = df.drop("rest_type", axis = 1)

# %% [markdown]
# **Handling Cuisines column**

# %%
#Handling Cuisines column
df["cuisines"].unique()
#Checking the no.of null values in cuisines column
df["cuisines"].isnull().sum()
#Checking most repeated cuisine
df["cuisines"].mode()
#Filling null values with most repeated value
df["cuisines"] = df["cuisines"].fillna("North Indian")
df["cuisines"].isnull().sum() #Removed null values
# Out:
# np.int64(0)

# %% [markdown]
# **Handling Approx_cost column**

# %%
#Handling approx_cost(for two people) column
df["approx_cost(for two people)"].unique()
#Checking the no.of null values in approx_cost(for two people) column
df["approx_cost(for two people)"].isnull().sum()

# Convert the column to string type
df["approx_cost(for two people)"] = df["approx_cost(for two people)"].astype(str)

# Removing commas from cost column
df["approx_cost(for two people)"] = df["approx_cost(for two people)"].str.replace(",", "")

# Converting cost column to float.
df["approx_cost(for two people)"] = pd.to_numeric(df["approx_cost(for two people)"], errors='coerce')

# Dropping rows where cost is missing
df.dropna(subset=["approx_cost(for two people)"], inplace=True)
df["approx_cost(for two people)"].isnull().sum() #Removed null values
# Out:
# np.int64(0)

# %% [markdown]
# **Handling listed_in(type) Column**

# %%
#Checking unique values
df["listed_in(type)"].unique()
#Checking null values
df["listed_in(type)"].isnull().sum() # It has 0 null values
#Renaming listed_in(type) to rest_type
df.rename(columns={"listed_in(type)": "rest_type"}, inplace=True)

# %% [markdown]
# **Handling listed_in(city) column**

# %%
#Checking  unique values
df["listed_in(city)"].unique()
#Checking null values
df["listed_in(city)"].isnull().sum() #It has 0 null values
# Out:
# np.int64(0)

# %% [markdown]
# #TASK 2: UNIVARIATE ANALYSIS

# %% [markdown]
# **1. Top 5 Locations with Highest Restaurants**

# %%
# Counting number of restaurants in each location
top_five_loc = df["location"].value_counts().head(5)
#Plotting bar chart
plt.bar(top_five_loc.index, top_five_loc.values)
plt.title("Top 5 Locations with Highest Number of Restaurants")
plt.xlabel("Location")
plt.ylabel("Number of Restaurants")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Interpretation:**
# The above chart shows the top 5 locations with the highest number of restaurants.
# The location BTM has highest no.of restaurants.

# %% [markdown]
# **2. Distribution of restaurant ratings**

# %%
# Plotting distribution of restaurant ratings
plt.hist(df["rate"], bins=10, color="red", edgecolor="black")
plt.title("Distribution of Restaurant Ratings")
plt.xlabel("Rating")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# **Interpretation:**
# Most restaurants have ratings between 3.5 and 4.5.
# Very few restaurants have ratings below 3.0.
# Overall majority of restaurants maintain good ratings.

# %% [markdown]
# **3️.Percentage of Restaurants Offering Online Orders**

# %%
# Counting online order availability
online = df["online_order"].value_counts()
# Plotting pie chart
plt.pie(online.values, labels=online.index, autopct="%1.1f%%")

plt.title("Percentage of Restaurants Offering Online Orders")

plt.show()

# %% [markdown]
# **Interpretation:**
#
# The chart shows the percentage of restaurants that offer online ordering services.
# Majority of restaurants provide online order facility.
# This indicates that online deliveris are more.

# %% [markdown]
# **4.Distribution of Average Cost for Two**

# %%
# 4)Distribution of average cost for two

plt.figure(figsize=(8,5))
sns.histplot(df["approx_cost(for two people)"],bins = 30, kde=True)
plt.xlabel("Cost for Two")
plt.ylabel("Number of Restaurants")
plt.title("Distribution of Average Cost for Two")
plt.show()

# %% [markdown]
# **Interpretation:**
#
# Most restaurants are mid-range.
# Only a few restaurants are very high-cost.
# This suggests customers prefer mid-range pricing.

# %% [markdown]
# # TASK 3: BIVARIATE ANALYSIS

# %% [markdown]
# ### **Analysing the relationships**

# %% [markdown]
#    **Rating vs Cost**

# %%
# Scatter plot for Rating vs Cost
plt.scatter(df["approx_cost(for two people)"], df["rate"], color="red")

plt.title("Rating vs Cost")
plt.xlabel("Cost for Two")
plt.ylabel("Rating")

plt.show()

# %% [markdown]
# **Conclusion:**
#
# The scatter plot shows the relationship between cost and rating.
# Many medium-cost restaurants also have high ratings.

# %% [markdown]
# **Rating vs Online Order**

# %%
# Boxplot for Rating vs Online Order
sns.boxplot(x="online_order", y="rate", data=df, color="red")

plt.title("Rating vs Online Order")
plt.xlabel("Online Order")
plt.ylabel("Rating")

plt.show()

# %% [markdown]
# **Conclusion:**
# Online availability may positively impact customer satisfaction.

# %% [markdown]
# **Votes vs Rating**

# %%
# Scatter plot for Votes vs Rating
plt.scatter(df["votes"], df["rate"], color="red")

plt.title("Votes vs Rating")
plt.xlabel("Votes")
plt.ylabel("Rating")

plt.show()

# %% [markdown]
# **Conclusion:**
#
# Restaurants with higher votes generally have higher ratings.
# This suggests popular restaurants often maintain good quality.

# %% [markdown]
# # Task 4: Business Insights & Recommendations

# %% [markdown]
# **1. Does higher cost lead to higher ratings?**
#
# From the scatter plot, it is clear that higher-priced restaurants do not always receive higher ratings.
# Many restaurants with moderate pricing also have very good ratings.

# %% [markdown]
# **2. Does offering online order impact ratings?**
# From the box plot, we can see that restaurants offering online orders have slightly better ratings compared to those that do not.
# This suggests that customers may prefer the convenience of online ordering.
# The difference is small, so online ordering alone does not completely determine the rating.

# %% [markdown]
# **3. Which location appears highly competitive?**
#  The location with the highest number of restaurants appears to be the most competitive.

# %% [markdown]
# **4.Where would you recommend opening a new restaurant?**
# It would be better to open a new restaurant in a location with moderate competition and good customer demand.

# %%
df.to_csv("cleaned_dataset")
